# %% [markdown]
# <a href="https://colab.research.google.com/github/danmargs/transformes/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/danmargs/transformes/
# Out:
# Cloning into 'transformes'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 86 (delta 18), reused 79 (delta 14), pack-reused 0
# Unpacking objects: 100% (86/86), done.

# %%
# %cd /content/transformes/
# Out:
# /content/transformes

# %%
# !python prepare_datasets.py --train_source=data/example/raw/src-train.txt --train_target=data/example/raw/tgt-train.txt
# Out:
# Done datasets preparation.

# %%
# !python train.py --data_dir=data/example/processed --save_config=checkpoints/example_config.json --save_checkpoint=checkpoints/example_model.pth --save_log=logs/example.log
# Out:
# [INFO] 2020-09-24 15:41:32 > Run name : d_model=128-layers_count=6-heads_count=4-pe=False-optimizer=Noam-2020_09_24_15_41_32
# [INFO] 2020-09-24 15:41:32 > {'config': None, 'data_dir': 'data/example/processed', 'save_config': 'checkpoints/example_config.json', 'save_checkpoint': 'checkpoints/example_model.pth', 'save_log': 'logs/example.log', 'device': 'cpu', 'dataset_limit': None, 'print_every': 1, 'save_every': 1, 'vocabulary_size': None, 'positional_encoding': False, 'd_model': 128, 'layers_count': 6, 'heads_count': 4, 'd_ff': 128, 'dropout_prob': 0.2, 'label_smoothing': 0.1, 'optimizer': 'Noam', 'lr': 0.001, 'clip_grads': False, 'batch_size': 64, 'epochs': 100}
# [INFO] 2020-09-24 15:41:32 > Constructing dictionaries...
# [INFO] 2020-09-24 15:41:32 > Source dictionary vocabulary : 484 tokens
# [INFO] 2020-09-24 15:41:32 > Target dictionary vocabulary : 76 tokens
# [INFO] 2020-09-24 15:41:32 > Building model...
# [INFO] 2020-09-24 15:41:32 > Transformer(
# ...

# %%
# !python predict_mod.py --source="test/input.txt" --config=checkpoints/example_config.json --checkpoint=checkpoints/example_model.pth
# Out:
# Constructing dictionaries...
# Building model...

# %%
# !git config user.email "daniele.margiotta11@gmail.com"
# !git config user.name "danmargs"
# !git add .
# !git commit -m "train-test"
# !git push origin master
# Out:
# [master f8faf52] train-test
#  21 files changed, 1505 insertions(+), 1435 deletions(-)
#  create mode 100644 __pycache__/beam.cpython-36.pyc
#  create mode 100644 __pycache__/datasets.cpython-36.pyc
#  create mode 100644 __pycache__/dictionaries.cpython-36.pyc
#  create mode 100644 __pycache__/embeddings.cpython-36.pyc
#  create mode 100644 __pycache__/losses.cpython-36.pyc
#  create mode 100644 __pycache__/metrics.cpython-36.pyc
#  create mode 100644 __pycache__/models.cpython-36.pyc
#  create mode 100644 __pycache__/optimizers.cpython-36.pyc
#  create mode 100644 __pycache__/predictors.cpython-36.pyc
#  create mode 100644 __pycache__/trainer.cpython-36.pyc
#  rewrite logs/example.log (62%)
#  create mode 100644 utils/__pycache__/log.cpython-36.pyc
#  create mode 100644 utils/__pycache__/pad.cpython-36.pyc
#  create mode 100644 utils/__pycache__/pipe.cpython-36.pyc
# fatal: could not read Username for 'https://github.com': No such device or address
